# %% [markdown]
# # Basic DL models
#
# This notebook compares three series of DL models to predict the survival of cancer samples:
#
# 1. **unimodal** — using only clinical data (age, sexe, etc.)
# 2. **bimodal** — using clinical data and RNA-seq data (bulk, protein-coding genes)
# 2. **multimodal** — using clinical data, RNA-seq data and images (from anatomopathological examination)
#
# All kinds of models predict a **log partial hazard** (Cox linear predictor) for each sample.
# A higher log partial hazard score indicates a higher predicted risk of death, and therefore a shorter expected survival time.

# %%
import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## 1. Unimodal models

# %% [markdown]
# ### a. Perceptron
#
# toto

# %% [markdown]
# ### b. toto
#
# toto

# %% [markdown]
# ## 2. Bimodal models

# %% [markdown]
# ### a. Perceptron
#
# toto

# %% [markdown]
# ## 3. Multimodal models

# %% [markdown]
# ### a. Perceptron
#
# toto
